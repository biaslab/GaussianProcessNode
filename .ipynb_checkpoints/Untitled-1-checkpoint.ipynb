# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/PhD/GaussianProcessNode`

# %%
using RxInfer, ReactiveMP, GraphPPL, Rocket

# %%
using SpecialFunctions

# %%
function freq_ratio(λ_prev, λ_present)
    f_prev = λ_prev ./ sum(λ_prev)
    f_present = λ_present ./ sum(λ_present)
    γ = f_present ./ f_prev
    return γ
end
# Out:
# freq_ratio (generic function with 1 method)

# %%
#create MvLogNormal node 
struct MvLogNormalMeanCovariance end 

@node MvLogNormalMeanCovariance Stochastic [ y, μ, Σ ]

@rule MvLogNormalMeanCovariance(:y, Marginalisation) (m_μ::PointMass, m_Σ::PointMass) = begin
   return MvLogNormal(m_μ, m_Σ) 
end

# %%
#create element-wise Poisson node 
struct ElementwisePoisson end 

@node ElementwisePoisson Stochastic [ y, x ]

@rule ElementwisePoisson(:y, Marginalisation) (q_x::Vector{GammaDistributionsFamily},) = begin
    α_x, β_x = Distributions.params.(q_x)
    λ = exp.(digamma.(α_x) .- log.(β_x))
    return Poisson.(λ)
end

@rule ElementwisePoisson(:x, Marginalisation) (q_y::Vector{Poisson},)= begin
    λ_y = mean.(q_y)
    return GammaShapeRate.(1 .+ λ_y, ones(length(λ_y)))
end

@rule ElementwisePoisson(:x, Marginalisation) (m_y::PointMass,)= begin
    λ_y = mean.(q_y)
    
    return GammaShapeRate.(1 .+ λ_y, ones(length(λ_y)))
end

# %%
#create element-wise Lognormal node 
struct ElementwiseLogNormal end 

@node ElementwiseLogNormal Stochastic [ y, μ, w ]

@rule ElementwiseLogNormal(:y, Marginalisation) (q_μ::MultivariateNormalDistributionsFamily, q_w::Vector{GammaDistributionsFamily},) = begin
    mean_μ = mean(q_μ)
    mean_w = mean.(q_w)
    σ = sqrt.(inv.(mean_w))
    return LogNormal.(mean_μ, σ)
end

@rule ElementwiseLogNormal(:μ, Marginalisation) (q_y::Vector{LogNormal}, q_w::Vector{GammaDistributionsFamily},) = begin
    μ_y = Distributions.params.(q_y)
    mean_w = mean.(q_w)

    return MvNormalMeanPrecision(μ_y, Diagonal(mean_w))
end

@rule ElementwiseLogNormal(:w, Marginalisation) (q_y::Vector{LogNormal}, q_μ::MultivariateNormalDistributionsFamily,) = begin
    μ_y, σ_y = Distributions.params.(q_y)
    mean_μ,cov_μ = mean_cov(q_μ)
    var_μ = diag(cov_μ)

    return GammaShapeRate.(3/2*ones(length(μ_y)),0.5.*(mean_μ^2 .+ var_μ .- 2 .* mean_μ.*μ_y .+ μ_y.^2 .+ σ_y.^2))
end

# %%
struct ElementwiseGammaShapeRate end 

@node ElementwiseGammaShapeRate Stochastic [ y, α, β ]

@rule ElementwiseGammaShapeRate(:y, Marginalisation) (m_α::PointMass, m_β::PointMass,) = begin
    return GammaShapeRate.(mean.(m_α), mean.(m_β))
end

@rule ElementwiseGammaShapeRate(:y, Marginalisation) (q_α::PointMass, q_β::PointMass, ) = begin 
    @show mean.(q_α)
    return GammaShapeRate.(mean.(q_α), mean.(q_β))
end

# %%
function ReactiveMP.prod(::ProdAnalytical,left::Vector{GammaDistributionsFamily}, right::Vector{GammaDistributionsFamily})
    T = promote_samplefloattype(left[1], right[1])
    return GammaShapeRate.(shape.(left) .+ shape.(right) .- one(T), rate.(left) .+ rate.(right))
end

# %%
@model function pop_dynamics(n_time, n_organ)
    y_data = datavar(Vector{Float64},n_time)
    λ = randomvar(n_time)
    s = randomvar()
    w = randomvar()
    γ = randomvar(n_time)

    #prior 
    s ~ MvNormalMeanCovariance(zeros(n_organ), diageye(n_organ))
    w ~ ElementwiseGammaShapeRate(zeros(n_organ), diageye(n_organ)) # this is the inverse of σ

    λ_0 ~ ElementwiseGammaShapeRate(0.01*ones(n_organ), 0.01*ones(n_organ))
    λ_prev = λ_0 
    #consider each time step
    for t=1:n_time 
        λ[t] ~ ElementwiseGammaShapeRate(0.01*ones(n_organ), 0.01*ones(n_organ)) #prior 
        y_data[t] ~ ElementwisePoisson(λ[t])
        γ[t] ~ freq_ratio(λ_prev,λ[t])
        γ[t] ~ ElementwiseLogNormal(s,w)
        λ_prev = λ[t]
    end
end

# %%
@meta function pop_dynamics_meta()
    freq_ratio() -> Linearization()
end
# Out:
# pop_dynamics_meta (generic function with 1 method)

# %%
@constraints function pop_dynamics_constraints()
    q(γ,s,w) = q(γ)q(s)q(w)
end
# Out:
# pop_dynamics_constraints (generic function with 1 method)

# %%
y_data = [50 20;68 23;81 35]
num_time = 3;
num_organ = 2;

# %%
nits =2

iresult = inference(
    model = pop_dynamics(num_time,num_organ),
    iterations = nits, 
    data  = (y = y_data,),
    meta = pop_dynamics_meta(),
    constraints = pop_dynamics_constraints(),
    returnvars = (s = KeepLast(),)
)
# Out:
# MethodError: no method matching length(::PointMass{Vector{Float64}})
# Closest candidates are:
#   length(::Union{Base.KeySet, Base.ValueIterator}) at abstractdict.jl:58
#   length(::Union{ZMQ._Message, Base.RefValue{ZMQ._Message}}) at ~/.julia/packages/ZMQ/lrABE/src/_message.jl:31
#   length(::Union{LinearAlgebra.Adjoint{T, <:Union{StaticArraysCore.StaticArray{Tuple{var"#s2"}, T, 1} where var"#s2", StaticArraysCore.StaticArray{Tuple{var"#s3", var"#s4"}, T, 2} where {var"#s3", var"#s4"}}}, LinearAlgebra.Diagonal{T, <:StaticArraysCore.StaticArray{Tuple{var"#s13"}, T, 1} where var"#s13"}, LinearAlgebra.Hermitian{T, <:StaticArraysCore.StaticArray{Tuple{var"#s10", var"#s11"}, T, 2} where {var"#s10", var"#s11"}}, LinearAlgebra.LowerTriangular{T, <:StaticArraysCore.StaticArray{Tuple{var"#s18", var"#s19"}, T, 2} where {var"#s18", var"#s19"}}, LinearAlgebra.Symmetric{T, <:StaticArraysCore.StaticArray{Tuple{var"#s7", var"#s8"}, T, 2} where {var"#s7", var"#s8"}}, LinearAlgebra.Transpose{T, <:Union{StaticArraysCore.StaticArray{Tuple{var"#s2"}, T, 1} where var"#s2", StaticArraysCore.StaticArray{Tuple{var"#s3", var"#s4"}, T, 2} where {var"#s3", var"#s4"}}}, LinearAlgebra.UnitLowerTriangular{T, <:StaticArraysCore.StaticArray{Tuple{var"#s24", var"#s25"}, T, 2} where {var"#s24", var"#s25"}}, LinearAlgebra.UnitUpperTriangular{T, <:StaticArraysCore.StaticArray{Tuple{var"#s21", var"#s22"}, T, 2} where {var"#s21", var"#s22"}}, LinearAlgebra.UpperTriangular{T, <:StaticArraysCore.StaticArray{Tuple{var"#s15", var"#s16"}, T, 2} where {var"#s15", var"#s16"}}, StaticArraysCore.StaticArray{Tuple{var"#s25"}, T, 1} where var"#s25", StaticArraysCore.StaticArray{Tuple{var"#s1", var"#s3"}, T, 2} where {var"#s1", var"#s3"}, StaticArraysCore.StaticArray{<:Tuple, T}} where T) at ~/.julia/packages/StaticArrays/VLqRb/src/abstractarray.jl:1
#   ...
#
# Stacktrace:
#    [1] _similar_shape(itr::PointMass{Vector{Float64}}, #unused#::Base.HasLength)
#      @ Base ./array.jl:663
#    [2] _collect(cont::UnitRange{Int64}, itr::PointMass{Vector{Float64}}, #unused#::Base.HasEltype, isz::Base.HasLength)
#      @ Base ./array.jl:718
#    [3] collect(itr::PointMass{Vector{Float64}})
#      @ Base ./array.jl:712
#    [4] broadcastable(x::PointMass{Vector{Float64}})
#      @ Base.Broadcast ./broadcast.jl:704
#    [5] broadcasted
#      @ ./broadcast.jl:1296 [inlined]
#    [6] macro expansion
#      @ ./In[8]:10 [inlined]
#    [7] (::var"#142#146"{Tuple{Marginal{PointMass{Vector{Float64}}, Nothing}, Marginal{PointMass{Vector{Float64}}, Nothing}}})()
#      @ Main ~/PhD/ReactiveMP.jl/src/rule.jl:426
#    [8] rule(fform::Type{ElementwiseGammaShapeRate}, on::Val{:y}, vconstraint::Marginalisation, messages_names::Nothing, messages::Nothing, marginals_names::Val{(:α, :β)}, marginals::Tuple{Marginal{PointMass{Vector{Float64}}, Nothing}, Marginal{PointMass{Vector{Float64}}, Nothing}}, meta::Nothing, addons#335::Nothing, node#336::Nothing)
#      @ Main ~/PhD/ReactiveMP.jl/src/rule.jl:428
#    [9] materialize!(mapping::ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}, messages::Nothing, marginals::Tuple{Marginal{PointMass{Vector{Float64}}, Nothing}, Marginal{PointMass{Vector{Float64}}, Nothing}})
#      @ ReactiveMP ~/PhD/ReactiveMP.jl/src/message.jl:325
#   [10] materialize!(mapping::ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}, dependencies::Tuple{Nothing, Tuple{Marginal{PointMass{Vector{Float64}}, Nothing}, Marginal{PointMass{Vector{Float64}}, Nothing}}})
#      @ ReactiveMP ~/PhD/ReactiveMP.jl/src/message.jl:315
#   [11] materialize!
#      @ ~/PhD/ReactiveMP.jl/src/message.jl:218 [inlined]
#   [12] as_message(vmessage::VariationalMessage{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}})
#      @ ReactiveMP ~/PhD/ReactiveMP.jl/src/message.jl:226
#   [13] MappingRF
#      @ ./reduce.jl:95 [inlined]
#   [14] _foldl_impl(op::Base.MappingRF{typeof(as_message), Base.BottomRF{ReactiveMP.var"#26#28"{ProdAnalytical}}}, init::Base._InitialValue, itr::Vector{AbstractMessage})
#      @ Base ./reduce.jl:58
#   [15] foldl_impl
#      @ ./reduce.jl:48 [inlined]
#   [16] mapfoldl_impl
#      @ ./reduce.jl:44 [inlined]
#   [17] #mapfoldl#259
#      @ ./reduce.jl:170 [inlined]
#   [18] mapfoldl
#      @ ./reduce.jl:170 [inlined]
#   [19] #foldl#260
#      @ ./reduce.jl:193 [inlined]
#   [20] foldl
#      @ ./reduce.jl:193 [inlined]
#   [21] (::ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint})(messages::Vector{AbstractMessage})
#      @ ReactiveMP ~/PhD/ReactiveMP.jl/src/message.jl:153
#   [22] next_received!(wrapper::Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}, data::VariationalMessage{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}, index::CartesianIndex{1})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/collected.jl:97
#   [23] on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/collected.jl:87 [inlined]
#   [24] scheduled_next!(actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}, value::VariationalMessage{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}, #unused#::AsapScheduler)
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/schedulers/asap.jl:23
#   [25] on_next!(subject::Subject{AbstractMessage, AsapScheduler, AsapScheduler}, data::VariationalMessage{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/subjects/subject.jl:62
#   [26] actor_on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:250 [inlined]
#   [27] next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:202 [inlined]
#   [28] on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/subjects/recent.jl:62 [inlined]
#   [29] actor_on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:250 [inlined]
#   [30] next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:202 [inlined]
#   [31] on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/map.jl:62 [inlined]
#   [32] next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:206 [inlined]
#   [33] next_received!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:101 [inlined]
#   [34] on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:68 [inlined]
#   [35] next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:206 [inlined]
#   [36] next_received!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:65 [inlined]
#   [37] on_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:34 [inlined]
#   [38] scheduled_next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/schedulers/asap.jl:23 [inlined]
#   [39] next!
#      @ ~/.julia/packages/Rocket/EGm1W/src/actor.jl:207 [inlined]
#   [40] on_subscribe!(observable::SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, actor::Rocket.CombineLatestUpdatesInnerActor{Marginal{PointMass{Vector{Float64}}, Nothing}, Rocket.CombineLatestUpdatesActorWrapper{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, Rocket.CombineLatestInnerActor{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.MapActor{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, scheduler::AsapScheduler)
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/single.jl:26
#   [41] scheduled_subscription!
#      @ ~/.julia/packages/Rocket/EGm1W/src/schedulers/asap.jl:21 [inlined]
#   [42] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:110 [inlined]
#   [43] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#   [44] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:118 [inlined]
#   [45] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#   [46] __combine_latest_updates_unrolled_fill_subscriptions!(sources::Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, wrapper::Rocket.CombineLatestUpdatesActorWrapper{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, Rocket.CombineLatestInnerActor{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.MapActor{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus})
#      @ Rocket ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127
#   [47] on_subscribe!(observable::Rocket.CombineLatestUpdatesObservable{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, PushNew}, actor::Rocket.CombineLatestInnerActor{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.MapActor{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:101
#   [48] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [49] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#   [50] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:154 [inlined]
#   [51] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#   [52] __combine_latest_unrolled_fill_subscriptions!(sources::Tuple{SingleObservable{Nothing, AsapScheduler}, Rocket.CombineLatestUpdatesObservable{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, PushNew}}, wrapper::Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.MapActor{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus})
#      @ Rocket ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127
#   [53] on_subscribe!(observable::Rocket.CombineLatestObservable{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Tuple{SingleObservable{Nothing, AsapScheduler}, Rocket.CombineLatestUpdatesObservable{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, PushNew}}, PushNew}, actor::Rocket.MapActor{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:137
#   [54] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [55] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#   [56] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [57] connect
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/connectable.jl:73 [inlined]
#   [58] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/ref_count.jl:72 [inlined]
#   [59] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [60] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#   [61] subscribe!(observable::ProxyObservable{AbstractMessage, Rocket.RefCountSource{AbstractMessage, ConnectableObservable{AbstractMessage, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ProxyObservable{AbstractMessage, Rocket.CombineLatestObservable{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, Tuple{SingleObservable{Nothing, AsapScheduler}, Rocket.CombineLatestUpdatesObservable{Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}, PushNew}}, PushNew}, Rocket.MapProxy{Tuple{Nothing, Tuple{SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}, SingleObservable{Marginal{PointMass{Vector{Float64}}, Nothing}, AsapScheduler}}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseGammaShapeRate, Val{:y}, Marginalisation, Nothing, Val{(:α, :β)}, Nothing, Nothing, Nothing}}}}}}, Rocket.RefCountProxy}, actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#   [62] on_subscribe!(observable::LazyObservable{AbstractMessage}, actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/lazy.jl:51
#   [63] subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/message.jl:243 [inlined]
#   [64] on_subscribe!(observable::Rocket.CollectLatestObservable{AbstractMessage, ReactiveMP.SkipIndexIterator{ReactiveMP.MessageObservable{AbstractMessage}, Vector{ReactiveMP.MessageObservable{AbstractMessage}}}, Message, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}, actor::Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/collected.jl:136
#   [65] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/subject.jl:59 [inlined]
#   [66] connect
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/connectable.jl:73 [inlined]
#   [67] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/ref_count.jl:72 [inlined]
#   [68] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [69] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#   [70] subscribe!(observable::ProxyObservable{Message, Rocket.RefCountSource{Message, ConnectableObservable{Message, Rocket.RecentSubjectInstance{Message, Subject{Message, AsapScheduler, AsapScheduler}}, Rocket.CollectLatestObservable{AbstractMessage, ReactiveMP.SkipIndexIterator{ReactiveMP.MessageObservable{AbstractMessage}, Vector{ReactiveMP.MessageObservable{AbstractMessage}}}, Message, ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}}, Rocket.RefCountProxy}, actor::Rocket.CombineLatestUpdatesInnerActor{Message, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.MapActor{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.CombineLatestUpdatesInnerActor{ReactiveMP.ManyOf, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, ReactiveMP.var"#277#278"}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#   [71] on_subscribe!(observable::LazyObservable{Message}, actor::Rocket.CombineLatestUpdatesInnerActor{Message, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.MapActor{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.CombineLatestUpdatesInnerActor{ReactiveMP.ManyOf, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, ReactiveMP.var"#277#278"}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/lazy.jl:51
#   [72] subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/message.jl:243 [inlined]
#   [73] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#   [74] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:118 [inlined]
#   [75] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#   [76] __combine_latest_updates_unrolled_fill_subscriptions!(sources::Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, wrapper::Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.MapActor{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.CombineLatestUpdatesInnerActor{ReactiveMP.ManyOf, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, ReactiveMP.var"#277#278"}, PushNew, Rocket.UInt8UpdatesStatus})
#      @ Rocket ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127
#   [77] on_subscribe!(observable::Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}, actor::Rocket.MapActor{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, Rocket.CombineLatestUpdatesInnerActor{ReactiveMP.ManyOf, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}}, ReactiveMP.var"#277#278"})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:101
#   [78] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [79] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#   [80] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [81] on_subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/node.jl:366 [inlined]
#   [82] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/subscribable.jl:188 [inlined]
#   [83] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#   [84] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:118 [inlined]
#   [85] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#   [86] __combine_latest_updates_unrolled_fill_subscriptions!
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#   [87] on_subscribe!(observable::Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, PushNew}, actor::Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:101
#   [88] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [89] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#   [90] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:154 [inlined]
#   [91] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#   [92] __combine_latest_unrolled_fill_subscriptions!(sources::Tuple{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, PushNew}, SingleObservable{Nothing, AsapScheduler}}, wrapper::Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}, PushNew, Rocket.UInt8UpdatesStatus})
#      @ Rocket ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127
#   [93] on_subscribe!(observable::Rocket.CombineLatestObservable{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Tuple{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, PushNew}, SingleObservable{Nothing, AsapScheduler}}, PushNew}, actor::Rocket.MapActor{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:137
#   [94] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [95] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#   [96] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#   [97] connect
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/connectable.jl:73 [inlined]
#   [98] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/ref_count.jl:72 [inlined]
#   [99] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [100] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [101] subscribe!(observable::ProxyObservable{AbstractMessage, Rocket.RefCountSource{AbstractMessage, ConnectableObservable{AbstractMessage, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ProxyObservable{AbstractMessage, Rocket.CombineLatestObservable{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, Tuple{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, PushNew}, SingleObservable{Nothing, AsapScheduler}}, PushNew}, Rocket.MapProxy{Tuple{Tuple{ReactiveMP.ManyOfObservable{Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MessageObservable{Message}, ReactiveMP.MessageObservable{Message}}, PushNew}}}, Nothing}, ReactiveMP.var"#1129#1130"{ReactiveMP.MessageMapping{DeltaFn{typeof(freq_ratio)}, Val{:out}, Marginalisation, Val{(:ins,)}, Nothing, DeltaMeta{Linearization, Nothing}, Nothing, DeltaFnNode{typeof(freq_ratio), 2, ReactiveMP.FactorNodeLocalMarginals{Tuple{ReactiveMP.FactorNodeLocalMarginal, ReactiveMP.FactorNodeLocalMarginal}}, DeltaMeta{Linearization, Nothing}}}}}}}}, Rocket.RefCountProxy}, actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#  [102] on_subscribe!(observable::LazyObservable{AbstractMessage}, actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/lazy.jl:51
#  [103] subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/message.jl:243 [inlined]
#  [104] on_subscribe!(observable::Rocket.CollectLatestObservable{AbstractMessage, Vector{ReactiveMP.MessageObservable{AbstractMessage}}, Marginal, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}, actor::Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/collected.jl:136
#  [105] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/subject.jl:59 [inlined]
#  [106] connect
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/connectable.jl:73 [inlined]
#  [107] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/ref_count.jl:72 [inlined]
#  [108] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [109] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [110] subscribe!(observable::ProxyObservable{Marginal, Rocket.RefCountSource{Marginal, ConnectableObservable{Marginal, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Rocket.CollectLatestObservable{AbstractMessage, Vector{ReactiveMP.MessageObservable{AbstractMessage}}, Marginal, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}}}, Rocket.RefCountProxy}, actor::Rocket.CombineLatestUpdatesInnerActor{Marginal, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#  [111] on_subscribe!(observable::LazyObservable{Marginal}, actor::Rocket.CombineLatestUpdatesInnerActor{Marginal, Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/lazy.jl:51
#  [112] subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/marginal.jl:142 [inlined]
#  [113] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#  [114] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:118 [inlined]
#  [115] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#  [116] __combine_latest_updates_unrolled_fill_subscriptions!(sources::Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, wrapper::Rocket.CombineLatestUpdatesActorWrapper{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}}, PushNew, Rocket.UInt8UpdatesStatus})
#      @ Rocket ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127
#  [117] on_subscribe!(observable::Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, PushNew}, actor::Rocket.CombineLatestInnerActor{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined_updates.jl:101
#  [118] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [119] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:55 [inlined]
#  [120] macro expansion
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:154 [inlined]
#  [121] macro expansion
#      @ ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127 [inlined]
#  [122] __combine_latest_unrolled_fill_subscriptions!(sources::Tuple{SingleObservable{Nothing, AsapScheduler}, Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, PushNew}}, wrapper::Rocket.CombineLatestActorWrapper{Rocket.MStorage2{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.MapActor{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}}, PushNew, Rocket.UInt8UpdatesStatus})
#      @ Rocket ~/.julia/packages/Unrolled/KtWta/src/Unrolled.jl:127
#  [123] on_subscribe!(observable::Rocket.CombineLatestObservable{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Tuple{SingleObservable{Nothing, AsapScheduler}, Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, PushNew}}, PushNew}, actor::Rocket.MapActor{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/combined.jl:137
#  [124] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [125] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [126] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [127] connect
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/connectable.jl:73 [inlined]
#  [128] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/ref_count.jl:72 [inlined]
#  [129] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [130] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [131] subscribe!(observable::ProxyObservable{AbstractMessage, Rocket.RefCountSource{AbstractMessage, ConnectableObservable{AbstractMessage, Rocket.RecentSubjectInstance{AbstractMessage, Subject{AbstractMessage, AsapScheduler, AsapScheduler}}, ProxyObservable{AbstractMessage, Rocket.CombineLatestObservable{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, Tuple{SingleObservable{Nothing, AsapScheduler}, Rocket.CombineLatestUpdatesObservable{Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}, PushNew}}, PushNew}, Rocket.MapProxy{Tuple{Nothing, Tuple{ReactiveMP.MarginalObservable, ReactiveMP.MarginalObservable}}, ReactiveMP.var"#341#342"{ReactiveMP.MessageMapping{ElementwiseLogNormal, Val{:μ}, Marginalisation, Nothing, Val{(:y, :w)}, Nothing, Nothing, Nothing}}}}}}, Rocket.RefCountProxy}, actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#  [132] on_subscribe!(observable::LazyObservable{AbstractMessage}, actor::Rocket.CollectLatestObservableInnerActor{AbstractMessage, CartesianIndex{1}, Rocket.CollectLatestObservableWrapper{AbstractMessage, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Vector{AbstractMessage}, BitVector, Vector{Teardown}, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/lazy.jl:51
#  [133] subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/message.jl:243 [inlined]
#  [134] on_subscribe!(observable::Rocket.CollectLatestObservable{AbstractMessage, Vector{ReactiveMP.MessageObservable{AbstractMessage}}, Marginal, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}, actor::Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/collected.jl:136
#  [135] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/subject.jl:59 [inlined]
#  [136] connect
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/connectable.jl:73 [inlined]
#  [137] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/operators/ref_count.jl:72 [inlined]
#  [138] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [139] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [140] subscribe!(observable::ProxyObservable{Marginal, Rocket.RefCountSource{Marginal, ConnectableObservable{Marginal, Rocket.RecentSubjectInstance{Marginal, Subject{Marginal, AsapScheduler, AsapScheduler}}, Rocket.CollectLatestObservable{AbstractMessage, Vector{ReactiveMP.MessageObservable{AbstractMessage}}, Marginal, ReactiveMP.var"#224#225"{ReactiveMP.var"#25#27"{ProdAnalytical, UnspecifiedFormConstraint}}}}}, Rocket.RefCountProxy}, actor::Rocket.FilterActor{Marginal, Rocket.TapActor{Marginal, StorageActor{Marginal}, RxInfer.var"#150#151"{RxInfer.MarginalHasBeenUpdated}}, ReactiveMP.var"#41#42"})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#  [141] on_subscribe!(observable::LazyObservable{Marginal}, actor::Rocket.FilterActor{Marginal, Rocket.TapActor{Marginal, StorageActor{Marginal}, RxInfer.var"#150#151"{RxInfer.MarginalHasBeenUpdated}}, ReactiveMP.var"#41#42"})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/observable/lazy.jl:51
#  [142] subscribe!
#      @ ~/PhD/ReactiveMP.jl/src/marginal.jl:142 [inlined]
#  [143] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [144] subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108 [inlined]
#  [145] on_subscribe!
#      @ ~/.julia/packages/Rocket/EGm1W/src/observable/proxy.jl:103 [inlined]
#  [146] subscribe!(observable::ProxyObservable{Marginal, ProxyObservable{Marginal, ReactiveMP.MarginalObservable, Rocket.FilterProxy{ReactiveMP.var"#41#42"}}, Rocket.TapProxy{RxInfer.var"#150#151"{RxInfer.MarginalHasBeenUpdated}}}, actor::StorageActor{Marginal})
#      @ Rocket ~/.julia/packages/Rocket/EGm1W/src/utils.jl:108
#  [147] (::RxInfer.var"#168#179"{Dict{Symbol, RxInfer.MarginalHasBeenUpdated}, Dict{Symbol, Any}, FactorGraphModel, Nothing})(::Pair{Symbol, StorageActor{Marginal}})
#      @ RxInfer ./none:0
#  [148] iterate
#      @ ./generator.jl:47 [inlined]
#  [149] grow_to!(dest::Dict{Any, Any}, itr::Base.Generator{Dict{Symbol, StorageActor{Marginal}}, RxInfer.var"#168#179"{Dict{Symbol, RxInfer.MarginalHasBeenUpdated}, Dict{Symbol, Any}, FactorGraphModel, Nothing}})
#      @ Base ./dict.jl:140
#  [150] dict_with_eltype
#      @ ./abstractdict.jl:584 [inlined]
#  [151] Dict(kv::Base.Generator{Dict{Symbol, StorageActor{Marginal}}, RxInfer.var"#168#179"{Dict{Symbol, RxInfer.MarginalHasBeenUpdated}, Dict{Symbol, Any}, FactorGraphModel, Nothing}})
#      @ Base ./dict.jl:129
#  [152] inference(; model::RxInfer.ModelGenerator{var"###pop_dynamics#369", Tuple{Int64, Int64}, NamedTuple{(), Tuple{}}}, data::NamedTuple{(:y,), Tuple{Matrix{Int64}}}, initmarginals::Nothing, initmessages::Nothing, constraints::ConstraintsSpecification{Tuple{ReactiveMP.FactorisationConstraintsSpecification{(:γ, :s, :w), (q(γ), q(s), q(w))}}, NamedTuple{(), Tuple{}}, NamedTuple{(), Tuple{}}}, meta::MetaSpecification{Tuple{ReactiveMP.MetaSpecificationEntry{0, Linearization}}}, options::Nothing, returnvars::NamedTuple{(:s,), Tuple{KeepLast}}, iterations::Int64, free_energy::Bool, free_energy_diagnostics::Tuple{BetheFreeEnergyCheckNaNs, BetheFreeEnergyCheckInfs}, showprogress::Bool, callbacks::Nothing, addons::Nothing, postprocess::DefaultPostprocess, warn::Bool, catch_exception::Bool)
#      @ RxInfer ~/PhD/RxInfer.jl/src/inference.jl:609
