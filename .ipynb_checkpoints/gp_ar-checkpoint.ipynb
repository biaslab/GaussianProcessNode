# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/PhD/GaussianProcessNode`

# %%
using Revise 
using StableRNGs, GraphPPL,ReactiveMP, RxInfer, Random, Distributions, LinearAlgebra, Plots
using Flux, Zygote, ForwardDiff
using SpecialFunctions, ForwardDiff, Optim
using BenchmarkTools
import KernelFunctions: SqExponentialKernel, Matern52Kernel, with_lengthscale, Kernel, kernelmatrix  
import ReactiveMP: GaussHermiteCubature
# import Functors: @functor
# Out:
# ┌ Info: Precompiling ReactiveMP [a194aa59-28ba-4574-a09c-4a745416d6e3]
# └ @ Base loading.jl:1664
# ┌ Info: Precompiling RxInfer [86711068-29c9-4ff7-b620-ae75d7495b3d]
# └ @ Base loading.jl:1664

# %% [markdown]
# ## Prepare data

# %%
function generate_data(n,x_0, f_gp, σ_x, σ_y)
    y=[]
    x = []
    x_prev = x_0
    for i=1:n
        x_t = σ_x * randn()
        temp = x_t * exp(f_gp[i])  
        push!(y,temp)
        push!(x,x_t)    
    end
    return x, y 
end
# Out:
# generate_data (generic function with 1 method)

# %%
Random.seed!(12)
σ_x = 2pi/10 
σ_y = 0.2
x_init = 0.0

N = 500; #data length
n = 500; #lenght of the axis of gp 
meanf = (x) -> 0.0;
kernel(θ) = with_lengthscale(SqExponentialKernel(),θ)
tmin,tmax = 0., 9.
time_range = collect(range(tmin, tmax; length=n));

θ_gp = 0.1
Cov_mat = kernelmatrix(kernel(θ_gp),time_range,time_range) + 1e-8*I;
gp = MvNormal(meanf.(time_range), Cov_mat)
f_test = rand(gp)

#Observe data 
pos = sort(randperm(n)[1:N]); # position where we observe data
time_train = time_range[pos]
f_train = f_test[pos];
cov_strategy = CovarianceMatrixStrategy(FullCovarianceStrategy())
# Out:
# CovarianceMatrixStrategy{FullCovarianceStrategy{Vector{Int64}, Nothing}}(FullCovarianceStrategy{Vector{Int64}, Nothing}(Int64[], nothing, [1.0;;], ReactiveMP.GPCache(Dict{Tuple{Symbol, Tuple{Int64, Int64}}, Matrix{Float64}}(), Dict{Tuple{Symbol, Int64}, Vector{Float64}}())))

# %%
#Generate data 
x_true_state, y_data = generate_data(N,x_init,f_train,σ_x,σ_y);

# %%
plot(exp.(f_train), label="gaussian process",linewidth=3.0)
plot!(x_true_state,label="AR staste",alpha=0.3)
plot!(y_data, label = "observations",alpha=0.3)

# %% [markdown]
# ## Specify model

# %%
#Exponentiate function 
struct MyExponential end

@node MyExponential Deterministic [ y,x ]   ## x: input,  y: output

# %%
### rule for y 
@rule MyExponential(:y, Marginalisation) (m_x::GaussianProcess, meta::ProcessMeta) = begin
    index = meta.index
    m_gp, cov_gp = mean_cov(m_x.finitemarginal)
#     μ_in = m_gp[index]
#     @show index
#     @show var_in = cov_gp[index,index]
    kernelf = m_x.kernelfunction
    meanf   = m_x.meanfunction
    test    = m_x.testinput
    train   = m_x.traininput
    cov_strategy = m_x.covariance_strategy
    x_u = m_x.inducing_input
    mμ, var_μ = ReactiveMP.predictMVN(cov_strategy, kernelf,meanf,test,[train[index]],m_gp, x_u) #this returns negative variance 
    μ_in = mμ[1]
    var_in = 0.1
#     var_μ[1] < 0. ? var_in = 1 : var_in = var_μ[1]
    return LogNormal(μ_in, var_in)
end

### rule for x
@rule MyExponential(:x, Marginalisation) (m_y::ContinuousUnivariateLogPdf, meta::ProcessMeta) = begin
    log_pdf = (x) -> logpdf(m_y,exp(x))
    return ContinuousUnivariateLogPdf(log_pdf)
end

@rule MyExponential(:y, Marginalisation) (m_x::UnivariateGaussianDistributionsFamily, meta::ProcessMeta) = begin 
    return LogNormal(mean(m_x), var(m_x))
end
    
@rule MyExponential(:x, Marginalisation) (m_y::UnivariateGaussianDistributionsFamily, meta::ProcessMeta) = begin 
    log_pdf = (x) -> logpdf(m_y,exp(x))
    return ContinuousUnivariateLogPdf(log_pdf)
end

# %%
#Test with GP with fixed hyperparameters
@model function randomwalk_gp(n, gp_kernel,gp_mean, train,test, gpstrategy, σ_x)
    x = randomvar(n)
    f = randomprocess(test, train, gpstrategy)
    y = datavar(Float64,n)
    g = randomvar(n)

    f ~ GaussianProcess(gp_mean, gp_kernel, log(θ_gp))
    x_0 ~ NormalMeanVariance(x_init, 50)
    x_prev = x_0 

    for i=1:n 
        x[i] ~ NormalMeanVariance(x_prev,σ_x^2)
        g[i] ~ MyExponential(f) where {meta = ProcessMeta(i)}
#         g[i] ~ takeExponential(f) where {
#             meta = (
#                 ProcessMeta(i), 
#                 DeltaMeta(method = CVI(100,1000,Descent(0.1)))
#             ),
# #             pipeline = RequireMessage(f = vague(NormalMeanVariance))
#         }
        # h[i] ~ (*)(x[i],g[i]) where {meta = (TinyCorrection(),)}
        y[i] ~ NormalMeanPrecision(x[i]*g[i], 1.5)
        x_prev = x[i]
    end
end

# %%
# function ReactiveMP.deltafn_rule_layout(factornode::DeltaFnNode, meta::Tuple{ProcessMeta,DeltaMeta})
#     return ReactiveMP.deltafn_rule_layout(factornode, ReactiveMP.getmethod(meta[2]), ReactiveMP.getinverse(meta[2]))
# end

# %%
@rule typeof(*)(:A, Marginalisation) (m_out::NormalMeanPrecision, m_in::Tuple, meta::TinyCorrection) = begin 
    μ_in = mean(m_in[1])
    var_in = mean(m_in[2])
    
    μ_out, var_out = mean_var(m_out)
    backwardpass = (x) -> -log(abs(x)) - 0.5*log(2π * (var_in + var_out / x^2))  -1/2 * (μ_out / x - μ_in)^2 / (var_in + var_out / x^2)
    return ContinuousUnivariateLogPdf(backwardpass)
end

@rule typeof(*)(:in, Marginalisation) (m_out::UnivariateGaussianDistributionsFamily, m_A::UnivariateGaussianDistributionsFamily, meta::TinyCorrection) = begin 
    μ_in, var_in = mean_var(m_A)
    μ_out, var_out = mean_var(m_out)
    backwardpass = (x) -> -log(abs(x)) - 0.5*log(2π * (var_in + var_out / x^2))  - 1/2 * (μ_out / x - μ_in)^2 / (var_in + var_out / x^2)

    return ContinuousUnivariateLogPdf(backwardpass)
end

# %%
# @rule DeltaFn(:out, Marginalisation) (m_ins::ManyOf{1, GaussianProcess}, meta::Tuple{ProcessMeta, DeltaMeta}) = begin 
#     gp_finitemarginal = m_ins[1].finitemarginal
#     # return @call_rule DeltaFn(:out, Marginalisation) (m_ins = gp_finitemarginal, meta = meta[2])
#     return ReactiveMP.approximate(ReactiveMP.getmethod(meta[2]), ReactiveMP.getnodefn(ReactiveMP.Val(:out)), gp_finitemarginal)
# end

# %%
# @constraints function gpconstraints()   
#     q(x_0,x,f,g) = q(x_0)q(x)q(f)q(h)
# end

# %%
#correct function 
# function besselmod(z,mx,vx,my,vy,n)
#     f_n = (y) -> mapreduce(m -> (z^(2y-m)*abs(z)^(m-y)*vx^(m-y-1)*(mx/vx)^m * binomial(2y,m) * (my/vy)^(2y-m)*besselk(m-y,abs(z)/sqrt(vx*vy))) / (pi * factorial(2y) * vy^(m-y+1)), +, 0:2*y)
#     return exp(-0.5 * (mx^2/vx + my^2/vy)) * mapreduce(f_n, +, 0:n)
# end

# %% [markdown]
# ## Rule for multiplication node

# %%
#use Gaussian GaussHermiteCubature to approximate 
#Temporarily put here 
function ReactiveMP.prod(::ProdAnalytical, left::UnivariateGaussianDistributionsFamily, right::ContinuousUnivariateLogPdf) 
    #we use Gaussian Hermite Cubature here, not ProdAnalytical 
    meta = GaussHermiteCubature(221)
    m,v = ReactiveMP.approximate_meancov(meta, z -> exp(right.logpdf(z)), mean(left), var(left))
    return NormalMeanVariance(m,v)
end

function ReactiveMP.prod(::ProdAnalytical, left::ContinuousUnivariateLogPdf, right::UnivariateGaussianDistributionsFamily)
    meta = GaussHermiteCubature(221)
    m,v = ReactiveMP.approximate_meancov(meta, z -> exp(left.logpdf(z)), mean(right), var(right))
    return NormalMeanVariance(m,v)
end

#Look carefully at these two functions 
function Distributions.mean(p::ContinuousUnivariateLogPdf)
    res = optimize(x -> -logpdf(p,x),-100,100)
    m0 = res.minimizer
    meta = GaussHermiteCubature(221)
    m,v = ReactiveMP.approximate_meancov(meta, z -> exp(p.logpdf(z)-logpdf(NormalMeanVariance(m0,10.0),z)), m0, 10.0)
    
    return m
end

function Distributions.var(p::ContinuousUnivariateLogPdf)
    m0 = Distributions.mean(p)
    dx = (x) -> ForwardDiff.derivative(p.logpdf,x)
    ddx = (x) -> ForwardDiff.derivative(dx,x)
    
    meta = GaussHermiteCubature(221)
    m,v = ReactiveMP.approximate_meancov(meta, z -> exp(p.logpdf(z)-logpdf(NormalMeanVariance(m0,10.0),z)), m0, 10.0)
    
#     if ddx(m0) < 0
#         return -inv(ddx(m0))
#     else
#         return 0.1
#     end
    return v
end

# %%
# function ReactiveMP.prod(::ProdAnalytical, left::Tuple, right::ContinuousUnivariateLogPdf)
#     μ_left = mean(left[1])
#     var_left = mean(left[2])

#     meta = GaussHermiteCubature(71)
#     m,v = ReactiveMP.approximate_meancov(meta, z -> exp(right.logpdf(z)), μ_left, var_left)
#     return NormalMeanVariance(m,v)
# end

function ReactiveMP.prod(::ProdAnalytical, left::LogNormal, right::ContinuousUnivariateLogPdf) 
#    @show μ_left, var_left = ReactiveMP.mean_var(left)
    sample_left = rand(left,1000)
    weights = [exp(logpdf(right,sample_left[i])) for i=1:1000]
    weight = weights / sum(weights)
    m = sum(weight .* sample_left)
    v = sum(weight .* (sample_left .- m).^2)
    # meta = GaussHermiteCubature(71)
    # m,v = ReactiveMP.approximate_meancov(meta, z -> exp(right.logpdf(z)), μ_left, var_left)
    return NormalMeanVariance(m,v)
end

# %%
# @marginalrule DeltaFn(:ins) (m_out::NormalMeanVariance, m_ins::ManyOf{1, GaussianProcess}, meta::Tuple{ProcessMeta, DeltaMeta{ProdCVI{Random._GLOBAL_RNG, Flux.Optimise.Adam, ForwardDiffGrad, true}, Nothing}}) = begin 
#     g = ReactiveMP.getnodefn(Val(:out))
    
#     gp_finitemarginal = m_ins[1].finitemarginal
#     m_gp, cov_gp = mean_cov(gp_finitemarginal)
#     index = meta[1].index
#     kernelf = m_ins[1].kernelfunction
#     test    = m_ins[1].testinput
#     meanf   = m_ins[1].meanfunction
#     train   = m_ins[1].traininput
#     cov_strategy = m_ins[1].covariance_strategy
#     x_u = m_ins[1].inducing_input

#     mean_gp, var_gp = ReactiveMP.predictMVN(cov_strategy, kernelf,meanf,test,[train[index]],m_gp, x_u) #changed here
#     # Create an `AbstractContinuousGenericLogPdf` with an unspecified domain and the transformed `logpdf` function
#     F = promote_variate_type(variate_form(first(NormalMeanVariance(mean_gp, var_gp))), AbstractContinuousGenericLogPdf)
#     f = convert(F, UnspecifiedDomain(), (z) -> logpdf(m_out, g(z)))
#     q = prod(getmethod(meta[2]), f, first(NormalMeanVariance(mean_gp, var_gp)))

#     return FactorizedJoint((q,))
# end

# %%
nits = 5
iresult = inference(
    model = randomwalk_gp(length(y_data), kernel, meanf, time_train,time_range, cov_strategy, σ_x),
    initmessages = (x_0 = NormalMeanVariance(0.,1.),f = GaussianProcess(meanf,kernel(θ_gp),MvNormalMeanCovariance(zeros(n),Cov_mat),time_range,time_train,Float64[], CovarianceMatrixStrategy(FullCovarianceStrategy()))),
    iterations = nits,  
    data  = (y = y_data,),
    free_energy = false
)

# f = GaussianProcess(meanf,kernel(θ_gp),MvNormalMeanCovariance(zeros(n),Cov_mat),time_range,time_train,Float64[], CovarianceMatrixStrategy(FullCovarianceStrategy())),
# Out:
# Inference results:
#   Posteriors       | available for (f, x_0, g, x)

# %%
mgp = mean(iresult.posteriors[:f][end].finitemarginal)
vgp = var(iresult.posteriors[:f][end].finitemarginal)
expvgp = exp.( mgp .+ vgp)
expmgp = exp.(mgp);

# %%
plot(expmgp,ribbon=sqrt.(expvgp),linewidth=3.0,label="estimated process",fillalpha=0.3)
plot!(exp.(f_test), label="gaussian process",linewidth=3.0)
# plot!(mean.(iresult.posteriors[:x][end]))
plot!(y_data)
#with 20 iterations

# %%
plot(exp.(mean(iresult.posteriors[:f][end].finitemarginal)),ibbon=sqrt.(diag(cov(iresult.posteriors[:f][end].finitemarginal))),linewidth=3.0,label="estimated process",fillalpha=0.3)
plot!(exp.(f_test), label="gaussian process",linewidth=3.0)

# %%
?@marginalrule
# Out:
#   Documentation placeholder

# %%
plot(mean.(iresult.posteriors[:x][end]),label="estimated state")
plot!(x_true_state,label="Noise",alpha=0.3)
plot!(mean(iresult.posteriors[:f][end].finitemarginal),ribbon=sqrt.(diag(cov(iresult.posteriors[:f][end].finitemarginal))),linewidth=3.0,label="estimated process",fillalpha=0.3)

# %%
plot(exp.(f_train), label="gaussian process",linewidth=3.0)
plot!(x_true_state,label="AR staste",alpha=0.3)
plot!(y_data, label = "observations",alpha=0.3)

# %%
q_x = iresult.posteriors[:x];
x_pos = [mean.(q_x[i]) for i=1:nits]
# Out:
# 9-element Vector{Vector{Float64}}:
#  [-0.007976818684471225, -0.00729846343477309, -0.0064439581844440465, -0.007123641229280867, -0.005892656468870103, -0.00583530027333929, -0.006714346995762743, -0.00559095646037988, -0.005161748599816495, -0.005346557304948966  …  0.2003978034564218, 0.2270589759280674, 0.2985084288321067, 0.24379659662443562, 0.20775371198885564, 0.2673034563226154, 0.3160641290068641, 0.26825870937135565, 0.33096146767154005, 0.5135471808098445]
#  [8.562553792299035, 9.02047277089929, 9.478461132421895, 9.936524047639486, 10.394650489711253, 10.852848360112905, 11.311112569327534, 11.769429046413022, 12.22780121270834, 12.686225626006236  …  2.9062785470941477, 3.04174255767665, 3.3534633694397122, 2.6434050975088534, 2.2173491210588407, 2.2626088411977316, 2.3778260669703006, 2.1612289455306355, 2.4847763890845447, 3.7253707511927394]
# ...

# %%
res = optimize(x -> -logpdf(m_in,x), -10,10)
μ_in_approx = res.minimizer
var_in_approx = cholinv(hessian(x -> -logpdf(m_in,x), [μ_in_approx]))

# %%
d = LogNormal(0.4, 5.);
res = optimize(x -> -logpdf(d,x), -10,20)
# Out:
# Results of Optimization Algorithm
#  * Algorithm: Brent's Method
#  * Search Interval: [-10.000000, 20.000000]
#  * Minimizer: 2.071839e-11
#  * Minimum: -9.571624e+00
#  * Iterations: 67
#  * Convergence: max(|x - x_upper|, |x - x_lower|) <= 2*(1.5e-08*|x|+2.2e-16): true
#  * Objective Function Calls: 68

# %%
m0 = res.minimizer
hessian(x -> -logpdf(d,x), m0)
# Out:
# 9.318539867599603e19

# %%
x -> -logpdf(d,x)
# Out:
# #51 (generic function with 1 method)

# %%
Distributions.logpdf
# Out:
# logpdf (generic function with 96 methods)

# %%
ReactiveMP.logpdf
# Out:
# logpdf (generic function with 96 methods)
